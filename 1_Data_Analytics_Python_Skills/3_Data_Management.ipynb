# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

print(pd.__version__)

# Load Data
dataset = load_dataset('lukebarousse/data_jobs')

# Convert dataset to pandas DataFrame
df = dataset['train'].to_pandas()

# Change string to datetime ('job_posted_date' column)
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# 2.2.3

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %% [markdown]
# #### Sampling Data

# %%
# Sampling Data
df.sample(10) #sample 10 random rows
# Out:
#             job_title_short  \
# 634327  Senior Data Analyst
# 416609         Data Analyst
# 11028         Data Engineer
# 323835        Data Engineer
# 393094        Data Engineer
# 22161          Data Analyst
# 666190         Data Analyst
# 143820       Data Scientist
# 678519         Data Analyst
# 562158       Data Scientist
#
#                                                 job_title  \
# 634327  Job | Senior Data Analyst Finance KPI's | Brussel
# 416609                        Data Analyst / Data Modeler
# 11028                                    Sr Data Engineer
# 323835                           Big Data Platform Intern
# 393094  Customer-Facing Data Engineer (Tech Lead & Sen...
# 22161                               Data Security Analyst
# 666190  Data Analyst (Measurement and Effectiveness Se...
# 143820                             Data Science Executive
# 678519                                       Data Analyst
# 562158                                Lead Data Scientist
#
# ...

# %%
df.sample(10,random_state=42) #sample 10 rows + set random state for reporducibilit
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %%
df_original = dataset['train'].to_pandas()

# %% [markdown]
# #### Copy DataFrame

# %%
df_original.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
len(df) #oringial dataset
# Out:
# 785741

# %%
df_filled = df_original.copy()
df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(df_filled['salary_year_avg'].median())

# %%
df_filled['salary_year_avg'].head()
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original['salary_year_avg'].head() #does not change original df
#because they are saved as 2 seperate objects
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: salary_year_avg, dtype: float64

# %%
id(df_original), id(df_filled)
#dif ids because we copied the original df
# Out:
# (5588331024, 5183815824)
