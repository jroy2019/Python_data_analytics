# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

print(pd.__version__)

# Load Data
dataset = load_dataset('lukebarousse/data_jobs')

# Convert dataset to pandas DataFrame
df = dataset['train'].to_pandas()

# Change string to datetime ('job_posted_date' column)
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# 2.2.3

# %%
df.sample(15)
# Out:
#                   job_title_short  \
# 749940              Data Engineer
# 548936        Senior Data Analyst
# 732876               Data Analyst
# 88327                Data Analyst
# 138057  Machine Learning Engineer
# 453257             Data Scientist
# 543154             Cloud Engineer
# 73805           Software Engineer
# 767476      Senior Data Scientist
# 570406             Data Scientist
# 381328             Cloud Engineer
# 478239              Data Engineer
# 714533          Software Engineer
# 59733           Software Engineer
# 188742              Data Engineer
#
#                                                 job_title  \
# 749940                                 Big Data Developer
# 548936                           Senior Epic Data Analyst
# 732876                             Data Analyst frosinone
# 88327       Stock Data Analyst - £24,750 - Hull (On-site)
# 138057                          Machine Learning Engineer
# 453257                            Director - data science
# 543154                       Head of Engineering Platform
# 73805   Research Programmer Analyst - Smidt Heart Inst...
# 767476                                        Senior Data
# 570406                               Staff Data Scientist
# 381328                                     Cloud Engineer
# 478239                        Data & Convergence Engineer
# 714533                                  Platform Engineer
# 59733                            Senior Software Engineer
# 188742                                      Data Engineer
#
#                                    job_location              job_via  \
# 749940               Chennai, Tamil Nadu, India         via LinkedIn
# 548936                               Campus, IL            via BeBee
# 732876  Frosinone, Province of Frosinone, Italy            via BeBee
# 88327                                  Hull, UK      via Recruit.net
# 138057                                Argentina            via BeBee
# 453257                        Winston-Salem, NC            via BeBee
# 543154                                    Italy            via BeBee
# 73805                           Los Angeles, CA         via Mendeley
# 767476                                Singapore  via BeBee Singapore
# 570406                                 Anywhere         via LinkedIn
# 381328        Taguig, Metro Manila, Philippines            via BeBee
# 478239            Pisa, Province of Pisa, Italy     via Trabajo. Org
# 714533                      Carnaxide, Portugal   via BeBee Portugal
# 59733                  Bogotá, Bogota, Colombia            via BeBee
# 188742                              Bristol, UK        via WJHL Jobs
#
#                job_schedule_type  job_work_from_home  \
# 749940                 Full-time               False
# 548936                 Full-time               False
# 732876                 Part-time               False
# 88327                  Full-time               False
# 138057                 Full-time               False
# 453257                 Full-time               False
# 543154                 Full-time               False
# 73805                  Full-time               False
# 767476                Contractor               False
# 570406  Full-time and Contractor                True
# 381328                      None               False
# 478239                 Full-time               False
# 714533                      None               False
# 59733                  Full-time               False
# 188742                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 749940                      India 2023-10-02 20:35:29                   True
# 548936    Illinois, United States 2023-02-23 19:02:37                  False
# 732876                      Italy 2023-10-25 21:17:15                   True
# 88327              United Kingdom 2023-02-28 00:14:20                   True
# 138057                  Argentina 2023-11-25 08:09:49                  False
# 453257     Florida, United States 2023-04-25 14:04:58                  False
# 543154                      Italy 2023-09-15 19:12:54                  False
# 73805   California, United States 2023-01-18 00:01:52                  False
# 767476                  Singapore 2023-01-16 01:23:36                  False
# 570406       Texas, United States 2023-11-06 09:40:03                  False
# 381328                Philippines 2023-08-18 18:19:38                  False
# 478239                      Italy 2023-11-26 14:39:08                  False
# 714533                   Portugal 2023-07-16 02:23:45                  False
# 59733                    Colombia 2023-12-09 06:23:01                   True
# 188742             United Kingdom 2023-03-30 15:15:35                   True
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 749940                 False           India        None              NaN
# 548936                 False   United States        None              NaN
# 732876                 False           Italy        None              NaN
# 88327                  False  United Kingdom        None              NaN
# 138057                 False       Argentina        None              NaN
# 453257                  True   United States        None              NaN
# 543154                 False           Italy        None              NaN
# 73805                  False   United States        None              NaN
# 767476                 False       Singapore        None              NaN
# 570406                  True   United States        None              NaN
# 381328                 False     Philippines        None              NaN
# 478239                 False           Italy        None              NaN
# 714533                 False        Portugal        None              NaN
# 59733                  False        Colombia        None              NaN
# 188742                 False  United Kingdom        None              NaN
#
#         salary_hour_avg                                   company_name  \
# 749940              NaN                         Mobile Programming LLC
# 548936              NaN                                 Bozeman Health
# 732876              NaN                              TEMPI MODERNI SPA
# 88327               NaN                            In Technology Group
# 138057              NaN                                        Emprego
# 453257              NaN                         Reynolds American Inc.
# 543154              NaN                                  Confidenziale
# 73805               NaN                                     The Lancet
# 767476              NaN                                     Aon Hewitt
# 570406              NaN                                 Devoted Health
# 381328              NaN                                    Globe Group
# 478239              NaN                                       Vodafone
# 714533              NaN                                       Randstad
# 59733               NaN                                          Quora
# 188742              NaN  Anson McCade Ltd - IT and Finance Recruitment
#
#                                                job_skills  \
# 749940  ['sql', 'java', 'databricks', 'kafka', 'pyspar...
# 548936                                            ['sql']
# 732876                                          ['excel']
# 88327                                    ['sql', 'excel']
# 138057  ['python', 'bash', 'elasticsearch', 'pandas', ...
# 453257                             ['sql', 'python', 'r']
# 543154                                          ['azure']
# 73805                         ['sas', 'sas', 'r', 'spss']
# 767476  ['sql', 'r', 'python', 'ggplot2', 'tableau', '...
# 570406                             ['sql', 'python', 'r']
# 381328                 ['aws', 'gcp', 'vmware', 'redhat']
# 478239                            ['powerpoint', 'excel']
# 714533  ['no-sql', 'mongodb', 'mongodb', 'java', 'pyth...
# 59733   ['sql', 'aws', 'redshift', 'snowflake', 'spark...
# 188742                                               None
#
#                                           job_type_skills
# 749940  {'cloud': ['databricks'], 'libraries': ['kafka...
# 548936                           {'programming': ['sql']}
# 732876                       {'analyst_tools': ['excel']}
# 88327   {'analyst_tools': ['excel'], 'programming': ['...
# 138057  {'databases': ['elasticsearch'], 'libraries': ...
# 453257            {'programming': ['sql', 'python', 'r']}
# 543154                               {'cloud': ['azure']}
# 73805   {'analyst_tools': ['sas', 'spss'], 'programmin...
# 767476  {'analyst_tools': ['tableau', 'power bi'], 'li...
# 570406            {'programming': ['sql', 'python', 'r']}
# 381328  {'cloud': ['aws', 'gcp', 'vmware'], 'os': ['re...
# 478239         {'analyst_tools': ['powerpoint', 'excel']}
# 714533  {'analyst_tools': ['word'], 'cloud': ['aws', '...
# 59733   {'cloud': ['aws', 'redshift', 'snowflake'], 'l...
# 188742                                               None

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name = 'job_index'

# %%
df.sample(15)
#index row has name
# Out:
#                  job_title_short  \
# job_index
# 674197             Data Engineer
# 234936              Data Analyst
# 534059             Data Engineer
# 364892            Data Scientist
# 542876            Data Scientist
# 345855             Data Engineer
# 691976          Business Analyst
# 331655            Data Scientist
# 169849     Senior Data Scientist
# 44537               Data Analyst
# 4505                Data Analyst
# 538285            Data Scientist
# 334303            Data Scientist
# 496236              Data Analyst
# 711812            Data Scientist
#
#                                                    job_title  \
# job_index
# 674197                               Principal Data Engineer
# 234936                             Becario Análisis de Datos
# 534059                             Data Engineer con Inglese
# 364892                                   Data Scientist (gn)
# 542876                              Principal Data Scientist
# 345855                                         Data Engineer
# 691976                                               Analyst
# 331655                                        Data Scientist
# 169849                                 Senior Data Scientist
# 44537                               Calibration Data Analyst
# 4505                                    QM Data Professional
# 538285                                        Data Scientist
# 334303                         PhD candidate on data Science
# 496236     420742 | Data Visualization Analyst (SAS) [Hyb...
# 711812          AI/ML Health Data Scientist- Consultant Jobs
#
#                                               job_location  \
# job_index
# 674197                                       Liverpool, UK
# 234936                                              Mexico
# 534059     Vimercate, Province of Monza and Brianza, Italy
# 364892                      Leipzig, Germany   (+2 others)
# 542876                          Chennai, Tamil Nadu, India
# 345855          Cheonan-si, Chungcheongnam-do, South Korea
# 691976      Rome, Metropolitan City of Rome Capital, Italy
# 331655                           Mexico City, CDMX, Mexico
# 169849                                          London, UK
# 44537                                     Lisbon, Portugal
# 4505                                   Österreich, Austria
# 538285                                      Menlo Park, CA
# 334303                       's-Hertogenbosch, Netherlands
# 496236                   Makati, Metro Manila, Philippines
# 711812                                         Atlanta, GA
#
#                           job_via         job_schedule_type  \
# job_index
# 674197               via LinkedIn                Contractor
# 234936                  via BeBee  Full-time and Internship
# 534059                  via BeBee                 Full-time
# 364892             via Powercloud                 Full-time
# 542876               via LinkedIn                 Full-time
# 345855            via Recruit.net                 Full-time
# 691976     via Lavoro Trabajo.org                 Full-time
# 331655               via JobLeads                 Full-time
# 169849               via LinkedIn                 Full-time
# 44537          via BeBee Portugal                 Full-time
# 4505                    via BeBee   Full-time and Part-time
# 538285                  via BeBee                 Full-time
# 334303        via BeBee Nederland                 Full-time
# 496236                 via Indeed                 Full-time
# 711812         via Clearance Jobs                 Full-time
#
#            job_work_from_home            search_location     job_posted_date  \
# job_index
# 674197                  False             United Kingdom 2023-02-14 10:32:10
# 234936                  False                     Mexico 2023-10-30 07:08:42
# 534059                  False                      Italy 2023-02-22 19:38:08
# 364892                  False                    Germany 2023-07-23 23:30:43
# 542876                  False                      India 2023-11-06 20:04:18
# 345855                  False                South Korea 2023-01-21 00:29:45
# 691976                  False                      Italy 2023-03-15 10:15:16
# 331655                  False                     Mexico 2023-02-22 23:41:14
# 169849                  False             United Kingdom 2023-11-08 15:34:28
# 44537                   False                   Portugal 2023-11-09 06:41:35
# 4505                    False                    Austria 2023-10-12 13:38:40
# 538285                  False  California, United States 2023-08-29 19:05:55
# 334303                  False                Netherlands 2023-01-04 23:39:56
# 496236                  False                Philippines 2023-06-10 11:25:58
# 711812                  False                    Georgia 2023-01-26 03:39:10
#
#            job_no_degree_mention  job_health_insurance     job_country  \
# job_index
# 674197                      True                 False  United Kingdom
# 234936                      True                 False          Mexico
# 534059                     False                 False           Italy
# 364892                     False                 False         Germany
# 542876                     False                 False           India
# 345855                     False                 False     South Korea
# 691976                     False                 False           Italy
# 331655                     False                 False          Mexico
# 169849                     False                 False  United Kingdom
# 44537                      False                 False        Portugal
# 4505                       False                 False         Austria
# 538285                     False                 False   United States
# 334303                     False                 False     Netherlands
# 496236                      True                 False     Philippines
# 711812                     False                  True   United States
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 674197           None              NaN              NaN
# 234936           None              NaN              NaN
# 534059           None              NaN              NaN
# 364892           None              NaN              NaN
# 542876           None              NaN              NaN
# 345855           None              NaN              NaN
# 691976           None              NaN              NaN
# 331655           None              NaN              NaN
# 169849           None              NaN              NaN
# 44537            None              NaN              NaN
# 4505             None              NaN              NaN
# 538285           None              NaN              NaN
# 334303           None              NaN              NaN
# 496236           None              NaN              NaN
# 711812           None              NaN              NaN
#
#                              company_name  \
# job_index
# 674197                           Data Inc
# 234936                            BONALTO
# 534059                      Fincons Group
# 364892                    powercloud GmbH
# 542876                           ZoomInfo
# 345855                             DuPont
# 691976             Cattaneo Zanetto & Co.
# 331655                           Factumex
# 169849                           Elsevier
# 44537                    Experis Portugal
# 4505                   AUSTRIA JUICE GmbH
# 538285                               Meta
# 334303                 Tilburg University
# 496236     Monroe Consulting Phils., Inc.
# 711812                         Guidehouse
#
#                                                   job_skills  \
# job_index
# 674197                      ['python', 'sql', 'aws', 'jira']
# 234936                                   ['python', 'excel']
# 534059     ['javascript', 'java', 'postgresql', 'oracle',...
# 364892     ['python', 'java', 'bash', 'sql', 'no-sql', 'm...
# 542876                                     ['python', 'sql']
# 345855                   ['python', 'r', 'shell', 'pyspark']
# 691976                                                  None
# 331655                        ['aws', 'power bi', 'tableau']
# 169849                                                ['go']
# 44537                                                   None
# 4505                                                    None
# 538285                                ['sql', 'python', 'r']
# 334303                                            ['notion']
# 496236     ['sas', 'sas', 'sql', 'python', 'azure', 'tabl...
# 711812     ['r', 'python', 'sas', 'sas', 'sql', 'tableau'...
#
#                                              job_type_skills
# job_index
# 674197     {'async': ['jira'], 'cloud': ['aws'], 'program...
# 234936     {'analyst_tools': ['excel'], 'programming': ['...
# 534059     {'cloud': ['oracle'], 'databases': ['postgresq...
# 364892     {'async': ['confluence', 'jira'], 'cloud': ['a...
# 542876                    {'programming': ['python', 'sql']}
# 345855     {'libraries': ['pyspark'], 'programming': ['py...
# 691976                                                  None
# 331655     {'analyst_tools': ['power bi', 'tableau'], 'cl...
# 169849                               {'programming': ['go']}
# 44537                                                   None
# 4505                                                    None
# 538285               {'programming': ['sql', 'python', 'r']}
# 334303                                 {'async': ['notion']}
# 496236     {'analyst_tools': ['sas', 'tableau', 'excel'],...
# 711812     {'analyst_tools': ['sas', 'tableau', 'power bi...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_usa = df[df['job_country'] == 'United States']

# %% [markdown]
# reset_index() <br>
# reset index of a df from 1 to last index

# %%
df_usa.head()
df_usa.reset_index(inplace=True)

# %%
df_usa.head()
# Out:
#    job_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# 3       via LinkedIn                 Full-time               False
# 4   via ZipRecruiter                 Full-time                True
#
#            search_location     job_posted_date  job_no_degree_mention  \
# 0     Texas, United States 2023-06-16 13:44:15                  False
# 1     Texas, United States 2023-07-04 13:01:41                   True
# 2                  Georgia 2023-11-07 14:01:59                  False
# 3   Florida, United States 2023-03-27 13:18:18                  False
# 4  New York, United States 2023-04-23 13:02:57                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
# 1                 False  United States        None              NaN
# 2                 False  United States        None              NaN
# 3                 False  United States        None              NaN
# 4                 False  United States        None              NaN
#
#    salary_hour_avg                   company_name  \
# 0              NaN           Boehringer Ingelheim
# 1              NaN   Southwest Research Institute
# 2              NaN                smart folks inc
# 3              NaN  Miracle Software Systems, Inc
# 4              NaN     Radwell International, LLC
#
#                                           job_skills  \
# 0                                               None
# 1  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2                           ['python', 'sql', 'gcp']
# 3  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 4  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 0                                               None
# 1  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2  {'cloud': ['gcp'], 'programming': ['python', '...
# 3  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %% [markdown]
# set_index() <br>
# Changes index to index of another column in df

# %%
df_usa.set_index('job_index', inplace=True)

# %%
df_usa.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
median_pivot = df_usa.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc=['median','min','max'])
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0

# %%
median_pivot.sort_values(by=('median', 'salary_year_avg'), ascending=False, inplace=True)
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155000.0         55000.0        475000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Software Engineer                130000.0         48982.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Business Analyst                  90000.0         35000.0        387460.0
# Data Analyst                      90000.0         25000.0        375000.0

# %% [markdown]
# sort_index() <br>
# sorts an index no column name like sort_values

# %%
median_pivot.sort_index(inplace=True)
median_pivot #alpha order of first column by default
#sort index is good to sort by index (no column name needed)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0
