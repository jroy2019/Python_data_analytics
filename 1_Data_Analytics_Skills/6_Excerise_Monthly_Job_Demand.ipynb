# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

print(pd.__version__)

# Load Data
dataset = load_dataset('lukebarousse/data_jobs')

# Convert dataset to pandas DataFrame
df = dataset['train'].to_pandas()

# Change string to datetime ('job_posted_date' column)
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# 2.2.3

# %%
df_usa = df[df['job_country'] == 'United States'].copy()

# %%
df_usa.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 9        Data Scientist                                  Data Scientist II
#
#       job_location            job_via         job_schedule_type  \
# 0    Watertown, CT    via Work Nearby                 Full-time
# 3  San Antonio, TX  via Diversity.com                 Full-time
# 5         Anywhere   via ZipRecruiter  Contractor and Temp work
# 6     Dearborn, MI       via LinkedIn                 Full-time
# 9         Anywhere   via ZipRecruiter                 Full-time
#
#    job_work_from_home          search_location     job_posted_date  \
# ...

# %%
df_usa['job_month'] = df_usa['job_posted_date'].dt.strftime('%B')
df_usa.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 9        Data Scientist                                  Data Scientist II
#
#       job_location            job_via         job_schedule_type  \
# 0    Watertown, CT    via Work Nearby                 Full-time
# 3  San Antonio, TX  via Diversity.com                 Full-time
# 5         Anywhere   via ZipRecruiter  Contractor and Temp work
# 6     Dearborn, MI       via LinkedIn                 Full-time
# 9         Anywhere   via ZipRecruiter                 Full-time
#
#    job_work_from_home          search_location     job_posted_date  \
# ...

# %%
usa_pivot = df_usa.pivot_table(index='job_month',columns='job_title_short', aggfunc='size')

# %%
usa_pivot
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_month
# April                         565              40          6049
# August                        903              39          6634
# December                      648              40          3979
# February                      447              24          6124
# January                       527              36          8494
# July                          581              39          5201
# June                          446              32          5683
# March                         438              19          6218
# May                           279              20          4993
# November                      719              36          4531
# October                       932              48          5271
# September                     897              50          4639
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_month
# ...

# %%
usa_pivot.reset_index(inplace=True)

# %%
usa_pivot['month_num'] = pd.to_datetime(usa_pivot['job_month'], format ='%B').dt.month

# %%
usa_pivot
usa_pivot.sort_values(by='month_num', inplace=True)

# %%
usa_pivot
usa_pivot.set_index('job_month',inplace=True)

# %%
usa_pivot.drop(columns=['month_num'],inplace=True)

# %%
usa_pivot
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_month
# January                       527              36          8494
# February                      447              24          6124
# March                         438              19          6218
# April                         565              40          6049
# May                           279              20          4993
# June                          446              32          5683
# July                          581              39          5201
# August                        903              39          6634
# September                     897              50          4639
# October                       932              48          5271
# November                      719              36          4531
# December                      648              40          3979
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_month
# ...

# %%
usa_pivot.plot(kind='line') #messy
# Out:
# <Axes: xlabel='job_month'>

# %%
top_jobs = df_usa['job_title_short'].value_counts().head(3).index

# %%
usa_pivot_top_jobs = usa_pivot[top_jobs].copy()

# %%
usa_pivot_top_jobs
# Out:
# job_title_short  Data Analyst  Data Scientist  Data Engineer
# job_month
# January                  8494            6915           2655
# February                 6124            4956           3060
# March                    6218            4779           3183
# April                    6049            4867           2801
# May                      4993            4377           2976
# June                     5683            4645           2893
# July                     5201            4876           2570
# August                   6634            6318           3269
# September                4639            4568           3224
# October                  5271            4882           3015
# November                 4531            4175           2793
# December                 3979            3472           2641

# %%
usa_pivot_top_jobs.plot(kind='line')
plt.title('Monthly Job Postings for Popular Data Science Jobs in USA')
plt.xlabel('Month in 2023')
plt.ylabel('Number of Job Postings')
plt.show()
